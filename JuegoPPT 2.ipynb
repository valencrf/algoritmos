# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
    
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijeras'):
        return True
    
print(play())
# Out:
# Es un Empate

# %%
for i in range(5) :
    print(f"Ronda {i + 1}:")
    resultado = play()
    print(resultado)
    print()
# Out:
# Ronda 1:
# Es un Empate
#
# Ronda 2:
# Es un Empate
#
# Ronda 3:
# Es un Empate
#
# Ronda 4:
# ¡Perdiste!
#
# Ronda 5:
# ¡Perdiste!

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUWXYZabcdefghijklmnopqrstuvwxyz
import random
random.seed(1234) 
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUWXYZabcdefghijklmnopqrstuvwxyz'
password = ''
lenghtPW = int(input('que longitud quieres para tu pq'))
for _ in range(lenghtPW):
    password += random.choice(chars)
print(password)
# Out:
# f0!-x%,.

# %%
contraseña="Computadora"
contador=0

while True:
    contraseña_input = input("Introduzca una contraseña")
    contador +=1

    if contador > 3:
        print("Haz sobrepasado los intentos")

    elif contraseña_input == "Computadora":
        print("Contraseña correcta")
        break
    else:
        print("Contraseña incorrecta , Introduzca una contraseña correcta")
# Out:
# Contraseña correcta
